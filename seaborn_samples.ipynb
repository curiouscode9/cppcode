# %% [markdown]
# <a href="https://colab.research.google.com/github/curiouscode9/cppcode/blob/master/seaborn_samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import io;

# %matplotlib inline

 
import matplotlib.pyplot as plt
from scipy.stats import norm
from google.colab import files

from pylab import *


#whetherfile = sns.load_dataset("https://github.com/curiouscode9/curiouscode9-gmail.com/blob/master/AirQualityUCI.csv")
whetherfile = pd.read_csv("https://raw.githubusercontent.com/curiouscode9/curiouscode9-gmail.com/master/weather_small_2012.csv?token=APCNKQOQDWXBIPGOMOAIFSS66SBKQ")
#wine_counts = pd.read_csv("https://raw.githubusercontent.com/antrixsh/Data-Science-Practice-Data-Sets/master/Casestudy/top-five-wine-score-counts.csv")

# %%
whetherfile.head()
# Out:
#              Date/Time  Temp (C)  ...  Visibility (km)  Stn Press (kPa)
# 0  2012-01-01 00:00:00      -1.8  ...              8.0           101.24
# 1  2012-01-01 01:00:00      -1.8  ...              8.0           101.24
# 2  2012-01-01 02:00:00      -1.8  ...              4.0           101.26
# 3  2012-01-01 03:00:00      -1.5  ...              4.0           101.27
# 4  2012-01-01 04:00:00      -1.5  ...              4.8           101.23
#
# [5 rows x 7 columns]

# %%
whetherfile

#whetherinfo=sns.pairplot(df.drop("RH",axis=1).head, hue="CO(GT)",palette="viridis",size=2)
# Out:
#                 Date/Time  Temp (C)  ...  Visibility (km)  Stn Press (kPa)
# 0     2012-01-01 00:00:00      -1.8  ...              8.0           101.24
# 1     2012-01-01 01:00:00      -1.8  ...              8.0           101.24
# 2     2012-01-01 02:00:00      -1.8  ...              4.0           101.26
# 3     2012-01-01 03:00:00      -1.5  ...              4.0           101.27
# 4     2012-01-01 04:00:00      -1.5  ...              4.8           101.23
# ...                   ...       ...  ...              ...              ...
# 8779  2012-12-31 19:00:00       0.1  ...              9.7           100.13
# 8780  2012-12-31 20:00:00       0.2  ...              9.7           100.03
# 8781  2012-12-31 21:00:00      -0.5  ...              4.8            99.95
# 8782  2012-12-31 22:00:00      -0.2  ...              9.7            99.91
# 8783  2012-12-31 23:00:00       0.0  ...             11.3            99.89
#
# [8784 rows x 7 columns]

# %%
sns.pairplot(whetherfile)

# %%
#sns.pairplot(whetherfile.drop("Date/Time",axis=1), hue="Temp (C)",palette="viridis",size=2)

# %%
sns.relplot(x="Date/Time" , y="Temp (C)",hue="Visibility (km)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-80c656b7171b> in <module>()
# ----> 1 sns.relplot(x="Date/Time" , y="Temp (C)",hue="Visibility (km)")
#
# /usr/local/lib/python3.6/dist-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1658         sizes=sizes, size_order=size_order, size_norm=size_norm,
#    1659         markers=markers, dashes=dashes, style_order=style_order,
# -> 1660         legend=legend,
#    1661     )
#    1662
#
# ...
